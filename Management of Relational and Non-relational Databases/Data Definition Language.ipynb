# %% [markdown]
# ## Introduction to SQL DDL with Postgres

# %% [markdown]
# ### SQL DDL: Data Definition Language

# %% [markdown]
# https://www.youtube.com/watch?v=5XHiv2KGsuQ

# %% [markdown]
# ![image.png](attachment:5126cdb4-2b12-45bd-9d80-a2a5fe864582.png)

# %% [markdown]
# ## Creating Tables with CREATE TABLE

# %% [markdown]
# https://www.youtube.com/watch?v=_WtJUdS_u8s

# %% [markdown]
# ![image.png](attachment:2a7760b0-e4eb-4195-890e-b728922d1d93.png)

# %% [markdown]
# https://www.youtube.com/watch?v=55z7sj-x7Lw

# %% [markdown]
# ![image.png](attachment:5a6f091d-fa57-4bc9-8de7-58d776e556c6.png)

# %%
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:password@localhost:5432/student

# %%
# %%sql
# CREATE TABLE "students" (
#     "id" SERIAL,
#     "name" TEXT,
#     "rank" INTEGER
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/student
# Done.
# []

# %%
# %%sql
# SELECT *
# FROM student

# %% [markdown]
# The complete syntax documentation for CREATE TABLE is available in the Postgres docs(opens in a new tab). In this lesson, we won't be looking at all the available modifiers of this syntax, preferring instead to only cover the essentials.

# %% [markdown]
# https://www.postgresql.org/docs/9.6/sql-createtable.html

# %% [markdown]
# ![image.png](attachment:d093fbe6-bd54-4251-9688-e9582dc35cf5.png)

# %% [markdown]
# ![image.png](attachment:b3547333-7662-4ada-8e1c-3a8ce158f95b.png)

# %%
CREATE TABLE "employees" (
  "id" SERIAL,
  "emp_name" TEXT,
  "manager_id" INTEGER
);

CREATE TABLE "employee_phones" (
  "emp_id" INTEGER,
  "phone_number" TEXT
);

# %% [markdown]
# ## Creating Tables Exercise Solution

# %% [markdown]
# https://www.youtube.com/watch?v=e2uDai6FTBk

# %% [markdown]
# ![image.png](attachment:fb5bd332-b327-4eba-a202-e3909bdcf35a.png)

# %% [markdown]
# https://www.youtube.com/watch?v=iHXd8pzI2yc

# %% [markdown]
# ![image.png](attachment:729c3539-daa6-4866-9e45-42e8886e435d.png)

# %% [markdown]
# https://www.youtube.com/watch?v=Fw-3yNtMuF4

# %% [markdown]
# This is the complete SQL solution:

# %%
CREATE TABLE "employees" (
  "id" SERIAL,
  "emp_name" TEXT,
  "manager_id" INTEGER
);

CREATE TABLE "employee_phones" (
  "emp_id" INTEGER,
  "phone_number" TEXT
);

# %% [markdown]
# ## Numeric Data Types

# %% [markdown]
# https://www.youtube.com/watch?v=UN7hVdf1j3E

# %% [markdown]
# The first category of data types we'll be exploring are number types. Postgres offers a large variety of number types, which might seem paralyzing when deciding which to choose. In the next videos, we'll be dissecting these types, and finding out that the decision can be more straightforward than you think.
#
# You may follow this link to find the full documentation on Postgres Numeric Data Types(opens in a new tab).

# %% [markdown]
# https://www.postgresql.org/docs/9.6/datatype-numeric.html

# %% [markdown]
# ## Numeric Data Types: Integers

# %% [markdown]
# https://www.youtube.com/watch?v=3-EelW_KRLs

# %% [markdown]
# ![image.png](attachment:f94f9bfd-b2f4-4962-ace2-76dc6d08ec1b.png)

# %% [markdown]
# https://www.youtube.com/watch?v=jx2NHFvoags

# %% [markdown]
# When using a SERIAL type, if we don't give it a value when inserting data, Postgres will automatically generate the next integer in sequence, until the sequence is exhausted based on the range of serial we chose (small, regular, or big).

# %% [markdown]
# https://www.youtube.com/watch?v=FTbKXUOkd2w

# %% [markdown]
# Choosing the correct type of integer is crucial. Trying to insert a value larger than the range permitted by our choice will pose an error. If we find out that we chose the wrong type after our table has millions of data records, rectifying this could require bringing the database down for an extended period of time, as we'll see in later videos on altering table structure.

# %% [markdown]
# ## Numeric Data Types: Decimals

# %% [markdown]
# https://www.youtube.com/watch?v=B04IujIG3Qk

# %% [markdown]
# What we call a decimal number in normal English numbering is in fact represented by two categories of data types in postgres: exact decimal numbers, and inexact decimal numbers.

# %% [markdown]
# https://www.youtube.com/watch?v=v4_33wRpWWs

# %% [markdown]
# In the last video, we saw that Postgres allows us to move from one data type to another using a process called "casting", which is accomplished using the :: operator. This casting operator is not magical, and will only work in cases where it makes sense. For example, if we have the text '1.5', we can cast it into an exact numeric value using the notation '1.5'::NUMERIC.

# %% [markdown]
# https://www.youtube.com/watch?v=0ncpNl9OMeU

# %% [markdown]
# ![image.png](attachment:a85ab0c0-fe87-433a-9229-b3c5eaae4f98.png)

# %% [markdown]
# ![image.png](attachment:e40e670f-1438-40e0-a6b7-1dc1dec346dd.png)

# %% [markdown]
# ## Text Data Types

# %% [markdown]
# https://www.youtube.com/watch?v=xbLy0rrWjd8

# %% [markdown]
# ![image.png](attachment:cdc62281-b928-45e5-a174-3f1a8ad40829.png)

# %% [markdown]
# https://www.youtube.com/watch?v=7j1IntiRjv4

# %% [markdown]
# Even though TEXT and VARCHAR without limit are the same, you might want to use one over the other as an extremely simplified form of documentation: you might use VARCHAR to represent something unbounded, but that would fit on a single line, and TEXT to represent large amounts of text like the contents of a book or someone's biography.

# %% [markdown]
# https://www.youtube.com/watch?v=5sXtcFaTGeU

# %% [markdown]
# ![image.png](attachment:2aff047e-5f90-47ee-ac27-e1d1944de965.png)

# %% [markdown]
# ![image.png](attachment:0082d234-9293-4ed7-a3e3-a448d321af4a.png)

# %% [markdown]
# https://www.postgresql.org/docs/9.6/datatype-character.html

# %% [markdown]
# ## Date/Time Data Types

# %% [markdown]
# https://www.youtube.com/watch?v=5yJ0P0S7oz8

# %% [markdown]
# ![image.png](attachment:c2167cfc-965a-4bf2-88cc-11058de61633.png)

# %% [markdown]
# ![image.png](attachment:7de002f9-c084-4a60-9669-e95475ebbe40.png)

# %% [markdown]
# https://www.youtube.com/watch?v=L-npu7j1fJ4

# %% [markdown]
# You can check the timezone of a Postgres server by running the SHOW TIMEZONE command, and you can set the timezone of the server by running the SET TIMEZONE command.

# %% [markdown]
# https://www.youtube.com/watch?v=RYJ9Z5Gop0E

# %% [markdown]
# Postgres allows you to store a date/time both with and without a timezone, and they both have their uses.
#
# If you're scheduling an online meeting between people in different places in the world, you want to make sure they will convene at the same point in time, no matter where they're located! In this case, you want to make sure that you're storing the timezone shift along with your date/time.
#
# We’ll come back to the other use case shortly.

# %% [markdown]
# https://www.youtube.com/watch?v=m7Goz7dZeqU

# %% [markdown]
# When you store a date/time WITH TIME ZONE, Postgres internally stores the date/time in UTC, but shifts it according to the timezone of the server. This means that even if the time zone of the server changes, Postgres will still have the correct value.
#
# More precisely, the date/time is stored as a number of milliseconds since the "epoch", which is defined as 1970-01-01 00:00:00-00. This consequently means that the value is stored very efficiently, requiring only an integer.

# %% [markdown]
# https://www.youtube.com/watch?v=IIPPUqhysK4

# %% [markdown]
# If you're a music label, or a gaming company, who wants to release an album or a game on a specific date at 8AM, you usually want that to happen at 8AM for the user. This means you want to store the release date of your album or game without the timezone shift, thereby saying "8AM local time".

# %% [markdown]
# https://www.youtube.com/watch?v=BhUB4qonmQ8

# %% [markdown]
# Postgres provides the values CURRENT_DATE and CURRENT_TIMESTAMP in order to retrieve these current values. You can use these when comparing column values for a SELECT, or when inserting/updating data.

# %% [markdown]
# https://www.postgresql.org/docs/9.6/datatype-datetime.html

# %% [markdown]
# ![image.png](attachment:d3cd4879-e7f6-46d1-be29-98632d9f6385.png)

# %% [markdown]
# ## Other Data Types

# %% [markdown]
# https://www.youtube.com/watch?v=qMPnC3znISE

# %% [markdown]
# Postgres offers many data types that we won't have the time to explore in this course. Here, we've seen an example of that with the JSONB type, which allows us to store composite values inside a single column. Care should be taken when using this type in order to make sure we don't negate the benefits of normalized data.

# %% [markdown]
# https://www.youtube.com/watch?v=luRO33s-ypM

# %% [markdown]
# https://www.postgresql.org/docs/9.6/datatype.html

# %% [markdown]
# ![image.png](attachment:3c2e90ca-ef21-42ad-b409-81353510a1f1.png)

# %% [markdown]
# ## Exercise: Data Types

# %% [markdown]
# ![image.png](attachment:c133aeee-3d5b-4421-85f4-b057e79fab7a.png)

# %% [markdown]
# ## Solution: Data Types Exercise

# %% [markdown]
# https://www.youtube.com/watch?v=pnf84I_s06U

# %% [markdown]
# Here is the first part of my own approach, for customers and customer emails.

# %%
CREATE TABLE "customers" (
  "id" SERIAL,
  "first_name" VARCHAR,
  "last_name" VARCHAR,
  "phone_number" VARCHAR
);

CREATE TABLE "customer_emails" (
  "customer_id" INTEGER,
  "email_address" VARCHAR
);

# %% [markdown]
# https://www.youtube.com/watch?v=IIBmte-9564

# %% [markdown]
# Here is my approach to be able to store the desired room data.

# %%
CREATE TABLE "rooms" (
  "id" SERIAL,
  "floor" SMALLINT,
  "room_no" SMALLINT,
  "area_sqft" SMALLINT
);

# %% [markdown]
# https://www.youtube.com/watch?v=xBXqNj__vV0

# %% [markdown]
# And finally, my last piece of the exercise for reservations:

# %%
CREATE TABLE "reservations" (
  "id" SERIAL,
  "customer_id" INTEGER,
  "room_id" INTEGER,
  "check_in" DATE,
  "check_out" DATE
);

# %% [markdown]
# ## Modifying Table Structure with `ALTER TABLE`

# %% [markdown]
# https://www.youtube.com/watch?v=W4yhvx7HH5s

# %% [markdown]
# Once you've created a table, Postgres offers you the ability to modify its structure using ALTER TABLE. This doesn't remove your responsibility to carefully plan out your data schema! Modifying a table structure after millions of rows have been inserted could mean having to take your database or your whole application offline.
#
# In some cases, depending on your situation in terms of volume of data and throughput, another solution might be to create a new table with the structure you need, and migrate the data to it. This solution isn't without its pitfalls either.

# %% [markdown]
# https://www.youtube.com/watch?v=_H1W8ZQZrwM

# %% [markdown]
# You may use `ALTER TABLE` with `ADD COLUMN` in order to bring in a new column to an already existing table.

# %% [markdown]
# https://www.youtube.com/watch?v=ondhK-U4x1A

# %% [markdown]
# You may use `ALTER TABLE` with `ALTER COLUMN` to change the data type of an existing column in your table.

# %% [markdown]
# https://www.youtube.com/watch?v=RKwtQ2A_VeA

# %% [markdown]
# ![image.png](attachment:071bb29d-8347-4fbd-8bfa-1034a6e6f434.png)

# %% [markdown]
# You may use ALTER TABLE with DROP COLUMN to completely remove a column, as well as all the data that was ever stored in all rows for that column. This operation is destructive, and unless you have a database backup, the lost data is unrecoverable!
# ).

# %% [markdown]
# Follow this link for the full [Postgres `ALTER TABLE` documentation](https://www.postgresql.org/docs/9.6/sql-altertable.html).

# %% [markdown]
# ## Exercise: Modifying Table Structure

# %% [markdown]
# ![image.png](attachment:1f465407-c56c-44be-8804-d2c258683506.png)

# %% [markdown]
# ![image.png](attachment:361c55aa-1e3e-4340-a458-ea96f58549c3.png)

# %% [markdown]
# ## Solution: Modifying Table Structure Exercise

# %% [markdown]
# https://www.youtube.com/watch?v=M8Pb6kLcqY0

# %% [markdown]
# Once again, it’s always important to make sure you fully understand the existing schema before you start making modifications.

# %% [markdown]
# https://www.youtube.com/watch?v=3XZF-LqV-6I

# %%
ALTER TABLE "students" ALTER COLUMN "email_address" SET DATA TYPE VARCHAR;

# %% [markdown]
# https://www.youtube.com/watch?v=O4Ue1Uy3ITc

# %%
ALTER TABLE "courses" ALTER COLUMN "rating" SET DATA TYPE REAL;

# %% [markdown]
# https://www.youtube.com/watch?v=N9Db8SIfqf4

# %% [markdown]
# The main takeaway here is that the data type for numbers is crucial to get right - using the wrong type can destroy part of a desired value.

# %% [markdown]
# https://www.youtube.com/watch?v=J6MnpkNs5k0

# %%
ALTER TABLE "registrations" ALTER COLUMN "student_id" SET DATA TYPE INTEGER;

ALTER TABLE "registrations" ALTER COLUMN "course_id" SET DATA TYPE INTEGER;

# %% [markdown]
# ## Other DDL Commands

# %% [markdown]
# https://www.youtube.com/watch?v=pXYd8pmF13k

# %% [markdown]
# Postgres offers three other DDL commands: DROP, TRUNCATE, and COMMENT.

# %% [markdown]
# ![image.png](attachment:126fd94a-1166-4efc-a9fc-25681c895502.png)

# %% [markdown]
# https://www.youtube.com/watch?v=Ent4QJOpfOQ

# %% [markdown]
# `DROP TABLE` will completely remove a table's structure and all associated data from the database, and is a destructive operation. Unless you have a backup, there's no way to recover the lost data!

# %% [markdown]
# https://www.youtube.com/watch?v=KPAqpTyT-aQ

# %% [markdown]
# `TRUNCATE TABLE` keeps the table structure intact, but removes all the data in the table. If you add the optional `RESTART IDENTITY` to the command, a `SERIAL` column's sequence will have its next value reset to 1.
#
# Truncating a table is also a destructive operation, and the data is lost forever unless you have a backup.

# %% [markdown]
# https://www.youtube.com/watch?v=7wtbY5DPXQs

# %% [markdown]
# Finally, the `COMMENT` command allows you to add a text comment on a table's column. If describing a table using `\d table_name`, you won't see the comments. You'd have to use `\d+` in order to see the comments that were defined on a table.

# %% [markdown]
# ![image.png](attachment:093b84e0-007d-482d-9d1c-48d903c7b678.png)

# %% [markdown]
# ## Recap of SQL DDL

# %% [markdown]
# https://www.youtube.com/watch?v=pnP5u-qMvhY

# %% [markdown]
# ![image.png](attachment:f3daf6e8-13cf-4b35-8d39-533585dcb493.png)

# %% [markdown]
# https://www.postgresql.org/docs/9.6/ddl.html

# %% [markdown]
# ![image.png](attachment:b6fd3fcc-6063-4acc-9515-ab71460dd8bd.png)
